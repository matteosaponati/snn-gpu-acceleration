# %%
import torch

# %%
print(f' CUDA available: {torch.cuda.is_available()} \n MPS available: {torch.backends.mps.is_available()}')
# Out:
#  CUDA available: False
#  MPS available: True

# %%
## all the GPUs in the M1, M2 chip etc share one memory with the CPU, so it is not possible to index different GPUs
## you cannot do: cuda:0, cuda:1, etc

device = torch.device('mps:0') 
x = torch.tensor([1.,2.], device = device)
